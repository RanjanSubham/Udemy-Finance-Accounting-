# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Telecom Churn Dataset

# %% [markdown]
# # Types of churn

# %% [markdown]
# # 1) Tariff Plan Churn = Like one person use 750 plan of jio now he is using 395.
#
# # 2) Service Churn = Like one person is using Yearly  PLan now he start using Monthly Plan.
#
# # 3) Product Churn = Now one person using Pospaid sim and now he shift to Prepaid.It will be loss  for company like company generate more revenue from pospaid service charged.
#
# # 4) Usage Churn   = In This case person stop using Product and service.

# %% [markdown]
# # *****Scenario and Condition of Churners

# %% [markdown]
# # WHO DONT WANT TO CHURN

# %% [markdown]
# # 1)INERT SUBSCRIBER:
# Because its too complex or i don't have time or its nor worth it.
#
# # UNCONDITIONALLY LOYAL:
# 2)Because my operator is the best.

# %% [markdown]
# # Who Thought about churning

# %% [markdown]
# # 1)lOCKED IN CONTRACT AND SUBSCRIBER:
# I want to churn but i locked in a contract.
#
# # 2)Conditionally loyal:
# I want to churn but now i will wait give them some chance.
#
# # 3) Conditional Churner:
# Because i found a better  offer.
#
# # 4) LIFESTYLE MIGRATOR:
# Because my needs have  changed.
#
# # 5) Unsatisfied Churner:
# Beacause i am   not satisfied with the service of the product.

# %% [markdown]
# # Load Dataset

# %%
ch =  pd.read_csv("D:\Python\WA_Fn-UseC_-Telco-Customer-Churn.csv")
ch
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
ch.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
top_tenure = ch['tenure'].nlargest(n=1000).index
top_tenure
# Out:
# Int64Index([  28,   35,   59,   62,   94,  106,  109,  127,  140,  167,
#             ...
#             3503, 3779, 3783, 3800, 3979, 3986, 4265, 4287, 4301, 4375],
#            dtype='int64', length=1000)

# %%
top_tenure_df = ch.iloc[top_tenure]
top_tenure_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 28    5248-YGIJN    Male              0     Yes         No      72
# 35    6234-RAAPL  Female              0     Yes        Yes      72
# 59    5954-BDFSG  Female              0      No         No      72
# 62    0526-SXDJP    Male              0     Yes         No      72
# 94    9848-JQJTX    Male              0      No         No      72
# ...          ...     ...            ...     ...        ...     ...
# 3986  6242-FEGFD    Male              0     Yes         No      66
# 4265  2632-UCGVD    Male              1     Yes         No      66
# 4287  6425-YQLLO  Female              1     Yes         No      66
# 4301  7729-XBTWX    Male              0     Yes        Yes      66
# 4375  9896-UYMIE    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 28            Yes               Yes             DSL                  Yes  ...
# ...

# %%
numerical_column = [feature for feature in ch.columns if ch[feature].dtypes != "o"]
print("Number of numerical column:", len(numerical_column))
ch[numerical_column].head()
# Out:
# Number of numerical column: 21
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
sns.heatmap(ch.corr(numeric_only = True),annot = True)
# Out:
# <Axes: >

# %%
ch.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
ch.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
ch.shape
# Out:
# (7043, 21)

# %% [markdown]
# # Contract Analysis

# %%
ch.groupby("Contract").size()
# Out:
# Contract
# Month-to-month    3875
# One year          1473
# Two year          1695
# dtype: int64

# %% [markdown]
# # Most likely Month-to-Month customer are most churners because they are not binded with any contract

# %%
sns.countplot(x = "Contract",palette = "Purples" ,data = ch)
# Out:
# <Axes: xlabel='Contract', ylabel='count'>

# %% [markdown]
# # Churn analysis

# %%
ch["Contract_binary"] = ch["Contract"].map({"Month-to-month":0,"One year":1,"Two year":2})
# Month-to-Month = 0, one year = 1,Two year = 2

# %%
ch["Contract_binary"].isnull().sum()
# Out:
# 0

# %%
ch["Churn"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
ch["Churn"].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
type(ch["Churn"]).info
# Out:
# <function pandas.core.series.Series.info(self, verbose: 'bool | None' = None, buf: 'IO[str] | None' = None, max_cols: 'int | None' = None, memory_usage: 'bool | str | None' = None, show_counts: 'bool' = True) -> 'None'>

# %%
ch['Churn'] = np.where(ch['Churn']=='Yes',1,0)

# %%
#ch["Churn"] = ch["Churn"].map({"yes":1,"No":0})
# yes = 1 and No =0

# %%
ch["Churn"].isnull().sum()
# Out:
# 0

# %%
ch.groupby("Churn").size()
# Out:
# Churn
# 0    5174
# 1    1869
# dtype: int64

# %%
sns.countplot(x = "Churn",palette = "winter",data = ch)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %% [markdown]
# # # Contract vs Churner
#
# # According to this analysis most churners are belongs to one monthly contracts
# ** In monthly contract womens has done more churn than men
#
#
# ** IN one year or Two year contract mens are doing more churn than women

# %%
sns.barplot(x = "Contract", y = "Churn", data = ch,palette = "rainbow",hue = "gender")#According to this analysis most churners are belongs to one monthly contracts 
plt.show()

# %%
type("SeniorCitizen")
# Out:
# str

# %%
sns.countplot(x ="SeniorCitizen",palette = "gist_ncar", hue = "Churn",data =ch)
# Out:
# <Axes: xlabel='SeniorCitizen', ylabel='count'>

# %% [markdown]
# # Partner

# %%
ch["Partner"].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
ch.groupby("Partner").size()
# Out:
# Partner
# No     3641
# Yes    3402
# dtype: int64

# %% [markdown]
# # According to this analysis mostly unmarried people stop using this product

# %%
sns.countplot(x = "Partner",hue = "Churn",palette = "gist_ncar",data = ch)# According to this analysis mostly unmarried people stop using this product 
# Mostly married people are well settled and mature  so they want stable life or less looking for new sim offers.
# Out:
# <Axes: xlabel='Partner', ylabel='count'>

# %% [markdown]
# # StreamingMovies
# The people Who is not watching movie most likely stop using the product

# %%
sns.countplot(x = "StreamingMovies",hue = "Churn",palette = "winter", data  = ch)
# Out:
# <Axes: xlabel='StreamingMovies', ylabel='count'>

# %% [markdown]
# # Data Cleaning
#
# 1)Create a copy of base data for manupulation and processing

# %%
ch_base_data = ch.copy()

# %%
ch["TotalCharges"] = pd.to_numeric(ch["TotalCharges"], errors = "coerce")

# %%
ch_base_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
ch.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# Contract_binary      0
# dtype: int64

# %%
ch.value_counts().sum()
# Out:
# 7032

# %%
ch["TotalCharges"].value_counts().sum()
# Out:
# 7032

# %% [markdown]
# # Only 11 null values in total charges

# %%
ch.loc[ch['TotalCharges'].isnull() == True]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
ch["TotalCharges"].unique()
# Out:
# array([  29.85, 1889.5 ,  108.15, ...,  346.45,  306.6 , 6844.5 ])

# %%
ch["TotalCharges"] = ch["TotalCharges"].fillna(0)

# %%
ch["TotalCharges"].isnull().sum()
# Out:
# 0

# %%
# Group the tenure in bins of 12 months
labels = ["{0} - {1}".format(i, i + 11) for i in range(1, 72, 12)]

ch['tenure_group'] = pd.cut(ch.tenure, range(1, 80, 12), right=False, labels=labels)

# %% [markdown]
# # Tenure Analysis

# %%
ch["tenure_group"].value_counts()
# Out:
# 1 - 12     2175
# 61 - 72    1407
# 13 - 24    1024
# 25 - 36     832
# 49 - 60     832
# 37 - 48     762
# Name: tenure_group, dtype: int64

# %% [markdown]
# # Most churners belongs to 1-12 months using period

# %%
sns.countplot(x = "tenure_group",hue = "Churn",palette = "tab20",data = ch)
# Out:
# <Axes: xlabel='tenure_group', ylabel='count'>

# %%
tn = ch.loc[ch['tenure'].nlargest(n=5)]
tn
# Out:
#     customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 72  1891-QRQSA   Male              1     Yes        Yes      64          Yes
# 72  1891-QRQSA   Male              1     Yes        Yes      64          Yes
# 72  1891-QRQSA   Male              1     Yes        Yes      64          Yes
# 72  1891-QRQSA   Male              1     Yes        Yes      64          Yes
# 72  1891-QRQSA   Male              1     Yes        Yes      64          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... StreamingTV  \
# 72           Yes     Fiber optic            Yes  ...         Yes
# 72           Yes     Fiber optic            Yes  ...         Yes
# 72           Yes     Fiber optic            Yes  ...         Yes
# 72           Yes     Fiber optic            Yes  ...         Yes
# 72           Yes     Fiber optic            Yes  ...         Yes
#
#    StreamingMovies  Contract PaperlessBilling              PaymentMethod  \
# ...

# %%
sns.countplot(x = "tenure",palette = "tab20",hue = "Churn",data = tn)
# Out:
# <Axes: xlabel='tenure', ylabel='count'>

# %%
sns.countplot(x = "Churn",hue = "PhoneService",palette = "seismic",data = ch)
# Out:
# <Axes: xlabel='Churn', ylabel='count'>

# %%
ch.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'Contract_binary', 'tenure_group'],
#       dtype='object')

# %% [markdown]
# # MultipleLines Analysis
#
# most churners as not Multiplelines user

# %%
sns.countplot(x = "MultipleLines",hue = "Churn",palette = "winter",data = ch)
# Out:
# <Axes: xlabel='MultipleLines', ylabel='count'>

# %%
ch["Churn"].value_counts()
# Out:
# 0    5174
# 1    1869
# Name: Churn, dtype: int64

# %% [markdown]
# # Internet Service Analysis
#
# According to this analysis whosoever using internetservice with Fiber optic are Churns more.

# %%
sns.countplot(x = "InternetService",hue = "Churn",palette = "seismic",data = ch)
# Out:
# <Axes: xlabel='InternetService', ylabel='count'>

# %% [markdown]
# # OnlineSecurity Analysis
#
#
# According to this analysis whosoever is not using OnlineSecurity are Churns more.

# %%
sns.countplot(x = "OnlineSecurity",hue = "Churn",palette = "rainbow",data = ch)
# Out:
# <Axes: xlabel='OnlineSecurity', ylabel='count'>

# %%
ch.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'Contract_binary', 'tenure_group'],
#       dtype='object')

# %% [markdown]
# # Online Backups Analysis
# According to this analysis whosoever is not having OnlineBackups are Churns more.

# %%
sns.countplot(x = "OnlineBackup",hue = "Churn",palette = "winter",data = ch)
# Out:
# <Axes: xlabel='OnlineBackup', ylabel='count'>

# %% [markdown]
# # DeviceProtection Analysis
#
#
# According to this analysis the person dont have device Protection Churns more.

# %%
sns.countplot(x = "DeviceProtection",hue = "Churn",palette = "rainbow",data = ch)
# Out:
# <Axes: xlabel='DeviceProtection', ylabel='count'>

# %% [markdown]
# # TechSupport
# According to this analysis the person dont have TechSupport Churns more.

# %%
sns.countplot(x = "TechSupport",hue = "Churn",palette = "winter",data = ch)
# Out:
# <Axes: xlabel='TechSupport', ylabel='count'>

# %% [markdown]
# # StreamingTV Analysis

# %%
sns.countplot(x = "StreamingTV",hue = "Churn",palette = "rainbow",data = ch)
# Out:
# <Axes: xlabel='StreamingTV', ylabel='count'>

# %%
ch.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn',
#        'Contract_binary', 'tenure_group'],
#       dtype='object')

# %% [markdown]
# # PaymentMethod Analysis

# %%
sns.countplot(x = "PaymentMethod",hue = "Churn",palette = "rainbow",data = ch)
# Out:
# <Axes: xlabel='PaymentMethod', ylabel='count'>

# %%
ch["MonthlyCharges"].unique()
# Out:
# array([29.85, 56.95, 53.85, ..., 63.1 , 44.2 , 78.7 ])

# %% [markdown]
# # WE can plot all columns in a single step

# %%
for i, predictor in enumerate(ch):
    plt.figure(i)
    sns.countplot(data=ch, x=predictor, hue='Churn')
# Out:
# C:\Users\Subham Ranjan\AppData\Local\Temp\ipykernel_18980\3484135066.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(i)
